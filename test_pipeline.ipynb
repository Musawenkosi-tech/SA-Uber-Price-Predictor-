# %%
import sys
sys.path.append('.')

from main import run_pipeline

run_pipeline()
# Out:
# Pipeline complete ✅

# %%
import os
os.getcwd()
# Out:
# '/home/ea6ed96c-3368-4e43-a91e-b39087bb62eb/Uber_Price_Predictor'

# %%
import pandas as pd

# %%
df = pd.read_csv(r"data/processed_uber_data.csv")
df
# Out:
#           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0     2026-01-01 00:00:00         28.174908       -25.712636
# 1     2026-01-01 00:05:00         28.290143       -25.716709
# 2     2026-01-01 00:10:00         28.246399       -25.732385
# 3     2026-01-01 00:15:00         28.219732       -25.689273
# 4     2026-01-01 00:20:00         28.131204       -25.702338
# ...                   ...               ...              ...
# 9875  2026-02-04 16:50:00         28.124923       -25.659896
# 9876  2026-02-04 16:55:00         28.271531       -25.662296
# 9877  2026-02-04 17:00:00         28.279502       -25.745319
# 9878  2026-02-04 17:05:00         28.289342       -25.719630
# 9879  2026-02-04 17:15:00         28.143428       -25.732774
#
#       dropoff_longitude  dropoff_latitude  distance_km  hour  is_rush_hour  \
# 0             28.246000        -25.686186     8.443931     0         False
# 1             28.136902        -25.704071    17.116643     0         False
# ...

# %%
df = df[ df["distance_km"] <= 20]
df
# Out:
#           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0     2026-01-01 00:00:00         28.174908       -25.712636
# 1     2026-01-01 00:05:00         28.290143       -25.716709
# 2     2026-01-01 00:10:00         28.246399       -25.732385
# 3     2026-01-01 00:15:00         28.219732       -25.689273
# 4     2026-01-01 00:20:00         28.131204       -25.702338
# ...                   ...               ...              ...
# 9874  2026-02-04 16:45:00         28.263748       -25.700734
# 9875  2026-02-04 16:50:00         28.124923       -25.659896
# 9876  2026-02-04 16:55:00         28.271531       -25.662296
# 9877  2026-02-04 17:00:00         28.279502       -25.745319
# 9879  2026-02-04 17:15:00         28.143428       -25.732774
#
#       dropoff_longitude  dropoff_latitude  distance_km  hour  is_rush_hour  \
# 0             28.246000        -25.686186     8.443931     0         False
# 1             28.136902        -25.704071    17.116643     0         False
# ...

# %%
df["distance_km"].max()
# Out:
# 19.996536760514832

# %%
df[["distance_km","minute_per_km","duration_min", "surge_multiplier", "price"]] = df[["distance_km","minute_per_km","duration_min", "surge_multiplier","price"]].round(2)
df
# Out:
# C:\Users\Musa_\AppData\Local\Temp\ipykernel_35660\1130003259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["distance_km","minute_per_km","duration_min", "surge_multiplier", "price"]] = df[["distance_km","minute_per_km","duration_min", "surge_multiplier","price"]].round(2)
#           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0     2026-01-01 00:00:00         28.174908       -25.712636
# 1     2026-01-01 00:05:00         28.290143       -25.716709
# 2     2026-01-01 00:10:00         28.246399       -25.732385
# 3     2026-01-01 00:15:00         28.219732       -25.689273
# 4     2026-01-01 00:20:00         28.131204       -25.702338
# ...                   ...               ...              ...
# ...

# %%
df["surge_multiplier"].max()
# Out:
# 1.8

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [pickup_datetime, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, distance_km, hour, is_rush_hour, minute_per_km, duration_min, surge_multiplier, price]
# Index: []

# %%
df['trip_id'] = range(1001, 1001 + len(df))
df.to_csv(r"C:\Users\Musa_\Documents\Uber_Price_Predictor\data\processed_uber_data.csv", index=False)
df
# Out:
# C:\Users\Musa_\AppData\Local\Temp\ipykernel_35660\2104859012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['trip_id'] = range(1001, 1001 + len(df))
#           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0     2026-01-01 00:00:00         28.174908       -25.712636
# 1     2026-01-01 00:05:00         28.290143       -25.716709
# 2     2026-01-01 00:10:00         28.246399       -25.732385
# 3     2026-01-01 00:15:00         28.219732       -25.689273
# 4     2026-01-01 00:20:00         28.131204       -25.702338
# ...                   ...               ...              ...
# 9874  2026-02-04 16:45:00         28.263748       -25.700734
# 9875  2026-02-04 16:50:00         28.124923       -25.659896
# ...
